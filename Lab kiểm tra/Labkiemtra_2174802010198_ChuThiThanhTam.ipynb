# %% [markdown]
# # Đề kiểm tra lập trình nhập môn phân tích dữ liệu và học sâu

# %%
# Họ và Tên: Chu Thị Thanh Tâm
# MSSV: 2174802010198

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import numpy as np
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

# %%
#Bước 1: Load data
def load_dataset():
    X, y = load_iris(return_X_y=True)
    X = X[y!=2]
    y = y[y!=2]
    return X,y

X, y = load_dataset()
print(X.shape,y.shape)
# Out:
# (100, 4) (100,)

# %% [markdown]
# Kết quả: (100, 4) (100,)

# %%
#Trực quan hóa dữ liệu data
plt.scatter(X[:,0],X[:,1], c=y) 
plt.show()

# sifa10, coca, lá-sâu, chó mèo, chữ viết tay

# %% [markdown]
# Kết quả

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Bước 2: Định nghĩa mô hình hồi quy logistic bằng PyTorch
import torch.nn as nn
class LogisticRegressTorch(nn.Module):
    def __init__(self, n_features):
        super(LogisticRegressTorch, self).__init__()
        #Điền ở đây theo comment                # tạo một lớp tuyến tính (nn.Linear) với n_features đầu vào và 1 đầu ra
        self.linear = nn.Linear(n_features, 1)
    
    def forward(self, x):
        return torch.sigmoid(self.linear(x))

# %%
# Bước 3: Định nghĩa lớp dữ liệu
class IrisTorch(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.float32).unsqueeze(1)
    
    def __len__(self):
        return len(self.X)                                     #trả về số lượng mẫu trong tập dữ liệu (số lượng hàng trong self.X)
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]                        #trả về một cặp đặc trưng và nhãn tương ứng với chỉ số idx

# %%
# Tạo dữ liệu
dataset = IrisTorch(X, y)

# %%
# Bước 4: Chia tập dữ liệu thành tập huấn luyện và tập kiểm tra bằng cách chia ngẫu nhiên 70,30.
train_size = int(0.7 * len(dataset))                       #70% 
test_size = len(dataset) - train_size                      #30%
train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

# %%
# Tạo DataLoader
batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# Bước 5: Định nghĩa criterion và optimizer
n_features = X.shape[1]
model = LogisticRegressTorch(n_features)
criterion = nn.BCELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %%
# Huấn luyện mô hình
n_epochs = 100
train_losses = []
test_losses = []
test_accuracies = []

for epoch in range(n_epochs):
    model.train()
    train_loss = 0.0
    for inputs, targets in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * inputs.size(0)
    
    train_loss /= len(train_loader.dataset)
    train_losses.append(train_loss)
    
    # Đánh giá trên tập kiểm tra
    model.eval()
    test_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, targets in test_loader:
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            test_loss += loss.item() * inputs.size(0)
            
            predicted = (outputs >= 0.5).float()
            total += targets.size(0)
            correct += (predicted == targets).sum().item()
    
    test_loss /= len(test_loader.dataset)
    test_losses.append(test_loss)
    
    accuracy = correct / total
    test_accuracies.append(accuracy)
    
    print(f'Epoch {epoch+1}/{n_epochs}, Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/100, Train Loss: 2.1170, Test Loss: 1.6660, Test Accuracy: 0.5667
# Epoch 2/100, Train Loss: 1.9425, Test Loss: 1.4686, Test Accuracy: 0.5667
# Epoch 3/100, Train Loss: 1.7156, Test Loss: 1.3045, Test Accuracy: 0.5667
# Epoch 4/100, Train Loss: 1.5251, Test Loss: 1.1533, Test Accuracy: 0.5667
# Epoch 5/100, Train Loss: 1.3488, Test Loss: 1.0135, Test Accuracy: 0.5667
# Epoch 6/100, Train Loss: 1.1860, Test Loss: 0.8962, Test Accuracy: 0.5667
# Epoch 7/100, Train Loss: 1.0454, Test Loss: 0.7753, Test Accuracy: 0.5667
# Epoch 8/100, Train Loss: 0.9002, Test Loss: 0.6723, Test Accuracy: 0.5667
# Epoch 9/100, Train Loss: 0.7748, Test Loss: 0.6098, Test Accuracy: 0.5667
# Epoch 10/100, Train Loss: 0.6952, Test Loss: 0.5768, Test Accuracy: 0.5667
# Epoch 11/100, Train Loss: 0.6500, Test Loss: 0.5542, Test Accuracy: 0.5667
# Epoch 12/100, Train Loss: 0.6160, Test Loss: 0.5353, Test Accuracy: 0.5667
# Epoch 13/100, Train Loss: 0.5853, Test Loss: 0.5281, Test Accuracy: 0.5667
# Epoch 14/100, Train Loss: 0.5741, Test Loss: 0.5189, Test Accuracy: 0.7000
# Epoch 15/100, Train Loss: 0.5555, Test Loss: 0.5128, Test Accuracy: 0.7333
# Epoch 16/100, Train Loss: 0.5488, Test Loss: 0.5084, Test Accuracy: 0.9667
# Epoch 17/100, Train Loss: 0.5364, Test Loss: 0.5022, Test Accuracy: 0.9667
# Epoch 18/100, Train Loss: 0.5316, Test Loss: 0.4977, Test Accuracy: 1.0000
# Epoch 19/100, Train Loss: 0.5246, Test Loss: 0.4905, Test Accuracy: 0.9667
# Epoch 20/100, Train Loss: 0.5233, Test Loss: 0.4851, Test Accuracy: 0.9667
# Epoch 21/100, Train Loss: 0.5182, Test Loss: 0.4802, Test Accuracy: 1.0000
# Epoch 22/100, Train Loss: 0.5095, Test Loss: 0.4776, Test Accuracy: 1.0000
# Epoch 23/100, Train Loss: 0.5002, Test Loss: 0.4736, Test Accuracy: 1.0000
# Epoch 24/100, Train Loss: 0.4946, Test Loss: 0.4671, Test Accuracy: 1.0000
# Epoch 25/100, Train Loss: 0.4908, Test Loss: 0.4606, Test Accuracy: 1.0000
# Epoch 26/100, Train Loss: 0.4869, Test Loss: 0.4548, Test Accuracy: 1.0000
# Epoch 27/100, Train Loss: 0.4833, Test Loss: 0.4496, Test Accuracy: 1.0000
# Epoch 28/100, Train Loss: 0.4797, Test Loss: 0.4445, Test Accuracy: 1.0000
# Epoch 29/100, Train Loss: 0.4746, Test Loss: 0.4438, Test Accuracy: 1.0000
# Epoch 30/100, Train Loss: 0.4641, Test Loss: 0.4394, Test Accuracy: 1.0000
# Epoch 31/100, Train Loss: 0.4590, Test Loss: 0.4385, Test Accuracy: 1.0000
# Epoch 32/100, Train Loss: 0.4537, Test Loss: 0.4306, Test Accuracy: 1.0000
# Epoch 33/100, Train Loss: 0.4501, Test Loss: 0.4245, Test Accuracy: 1.0000
# Epoch 34/100, Train Loss: 0.4465, Test Loss: 0.4232, Test Accuracy: 1.0000
# Epoch 35/100, Train Loss: 0.4404, Test Loss: 0.4220, Test Accuracy: 1.0000
# Epoch 36/100, Train Loss: 0.4356, Test Loss: 0.4173, Test Accuracy: 1.0000
# Epoch 37/100, Train Loss: 0.4314, Test Loss: 0.4211, Test Accuracy: 1.0000
# Epoch 38/100, Train Loss: 0.4279, Test Loss: 0.4068, Test Accuracy: 1.0000
# Epoch 39/100, Train Loss: 0.4233, Test Loss: 0.4003, Test Accuracy: 1.0000
# Epoch 40/100, Train Loss: 0.4200, Test Loss: 0.3966, Test Accuracy: 1.0000
# Epoch 41/100, Train Loss: 0.4157, Test Loss: 0.3992, Test Accuracy: 1.0000
# Epoch 42/100, Train Loss: 0.4108, Test Loss: 0.3909, Test Accuracy: 1.0000
# Epoch 43/100, Train Loss: 0.4070, Test Loss: 0.3870, Test Accuracy: 1.0000
# Epoch 44/100, Train Loss: 0.4031, Test Loss: 0.3808, Test Accuracy: 1.0000
# Epoch 45/100, Train Loss: 0.3999, Test Loss: 0.3776, Test Accuracy: 1.0000
# Epoch 46/100, Train Loss: 0.3961, Test Loss: 0.3793, Test Accuracy: 1.0000
# Epoch 47/100, Train Loss: 0.3916, Test Loss: 0.3745, Test Accuracy: 1.0000
# Epoch 48/100, Train Loss: 0.3883, Test Loss: 0.3780, Test Accuracy: 1.0000
# Epoch 49/100, Train Loss: 0.3852, Test Loss: 0.3723, Test Accuracy: 1.0000
# Epoch 50/100, Train Loss: 0.3814, Test Loss: 0.3612, Test Accuracy: 1.0000
# Epoch 51/100, Train Loss: 0.3778, Test Loss: 0.3578, Test Accuracy: 1.0000
# Epoch 52/100, Train Loss: 0.3745, Test Loss: 0.3547, Test Accuracy: 1.0000
# Epoch 53/100, Train Loss: 0.3711, Test Loss: 0.3539, Test Accuracy: 1.0000
# Epoch 54/100, Train Loss: 0.3677, Test Loss: 0.3538, Test Accuracy: 1.0000
# Epoch 55/100, Train Loss: 0.3646, Test Loss: 0.3530, Test Accuracy: 1.0000
# Epoch 56/100, Train Loss: 0.3617, Test Loss: 0.3421, Test Accuracy: 1.0000
# Epoch 57/100, Train Loss: 0.3583, Test Loss: 0.3392, Test Accuracy: 1.0000
# Epoch 58/100, Train Loss: 0.3552, Test Loss: 0.3389, Test Accuracy: 1.0000
# Epoch 59/100, Train Loss: 0.3520, Test Loss: 0.3381, Test Accuracy: 1.0000
# Epoch 60/100, Train Loss: 0.3491, Test Loss: 0.3312, Test Accuracy: 1.0000
# Epoch 61/100, Train Loss: 0.3466, Test Loss: 0.3229, Test Accuracy: 1.0000
# Epoch 62/100, Train Loss: 0.3458, Test Loss: 0.3197, Test Accuracy: 1.0000
# Epoch 63/100, Train Loss: 0.3438, Test Loss: 0.3160, Test Accuracy: 1.0000
# Epoch 64/100, Train Loss: 0.3426, Test Loss: 0.3149, Test Accuracy: 1.0000
# Epoch 65/100, Train Loss: 0.3374, Test Loss: 0.3116, Test Accuracy: 1.0000
# Epoch 66/100, Train Loss: 0.3351, Test Loss: 0.3111, Test Accuracy: 1.0000
# Epoch 67/100, Train Loss: 0.3310, Test Loss: 0.3073, Test Accuracy: 1.0000
# Epoch 68/100, Train Loss: 0.3291, Test Loss: 0.3052, Test Accuracy: 1.0000
# Epoch 69/100, Train Loss: 0.3261, Test Loss: 0.3047, Test Accuracy: 1.0000
# Epoch 70/100, Train Loss: 0.3226, Test Loss: 0.3024, Test Accuracy: 1.0000
# Epoch 71/100, Train Loss: 0.3199, Test Loss: 0.3017, Test Accuracy: 1.0000
# Epoch 72/100, Train Loss: 0.3170, Test Loss: 0.2992, Test Accuracy: 1.0000
# Epoch 73/100, Train Loss: 0.3146, Test Loss: 0.2976, Test Accuracy: 1.0000
# Epoch 74/100, Train Loss: 0.3121, Test Loss: 0.2972, Test Accuracy: 1.0000
# Epoch 75/100, Train Loss: 0.3097, Test Loss: 0.2942, Test Accuracy: 1.0000
# Epoch 76/100, Train Loss: 0.3073, Test Loss: 0.2910, Test Accuracy: 1.0000
# Epoch 77/100, Train Loss: 0.3050, Test Loss: 0.2886, Test Accuracy: 1.0000
# Epoch 78/100, Train Loss: 0.3027, Test Loss: 0.2864, Test Accuracy: 1.0000
# Epoch 79/100, Train Loss: 0.3004, Test Loss: 0.2856, Test Accuracy: 1.0000
# Epoch 80/100, Train Loss: 0.2981, Test Loss: 0.2833, Test Accuracy: 1.0000
# Epoch 81/100, Train Loss: 0.2959, Test Loss: 0.2822, Test Accuracy: 1.0000
# Epoch 82/100, Train Loss: 0.2938, Test Loss: 0.2790, Test Accuracy: 1.0000
# Epoch 83/100, Train Loss: 0.2916, Test Loss: 0.2783, Test Accuracy: 1.0000
# Epoch 84/100, Train Loss: 0.2895, Test Loss: 0.2750, Test Accuracy: 1.0000
# Epoch 85/100, Train Loss: 0.2874, Test Loss: 0.2747, Test Accuracy: 1.0000
# Epoch 86/100, Train Loss: 0.2855, Test Loss: 0.2739, Test Accuracy: 1.0000
# Epoch 87/100, Train Loss: 0.2836, Test Loss: 0.2706, Test Accuracy: 1.0000
# Epoch 88/100, Train Loss: 0.2815, Test Loss: 0.2728, Test Accuracy: 1.0000
# Epoch 89/100, Train Loss: 0.2802, Test Loss: 0.2693, Test Accuracy: 1.0000
# Epoch 90/100, Train Loss: 0.2779, Test Loss: 0.2634, Test Accuracy: 1.0000
# Epoch 91/100, Train Loss: 0.2754, Test Loss: 0.2607, Test Accuracy: 1.0000
# Epoch 92/100, Train Loss: 0.2735, Test Loss: 0.2581, Test Accuracy: 1.0000
# Epoch 93/100, Train Loss: 0.2716, Test Loss: 0.2584, Test Accuracy: 1.0000
# Epoch 94/100, Train Loss: 0.2699, Test Loss: 0.2541, Test Accuracy: 1.0000
# Epoch 95/100, Train Loss: 0.2679, Test Loss: 0.2522, Test Accuracy: 1.0000
# Epoch 96/100, Train Loss: 0.2661, Test Loss: 0.2522, Test Accuracy: 1.0000
# Epoch 97/100, Train Loss: 0.2644, Test Loss: 0.2483, Test Accuracy: 1.0000
# Epoch 98/100, Train Loss: 0.2626, Test Loss: 0.2453, Test Accuracy: 1.0000
# Epoch 99/100, Train Loss: 0.2610, Test Loss: 0.2471, Test Accuracy: 1.0000
# Epoch 100/100, Train Loss: 0.2591, Test Loss: 0.2448, Test Accuracy: 1.0000

# %%
# Vẽ biểu đồ loss và accuracy

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(test_losses, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss vs Epochs')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(test_accuracies, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy vs Epochs')
plt.legend()

plt.show()

# %% [markdown]
# #Kết quả:

# %% [markdown]
# ![image.png](attachment:image.png)
